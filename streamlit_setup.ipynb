# %% [markdown]
# # 🚀 Streamlit Setup
#
# Quick setup to install Streamlit for building AI web applications.

# %% [markdown]
# ## 📦 Install Streamlit
#
# Choose your preferred package manager to install Streamlit:
#
# ### Option 1: pip (Recommended for most users)

# %%
# !pip install streamlit

# %% [markdown]
# ### Option 2: conda

# %%
# !conda install -c conda-forge streamlit
# Out:
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/Users/matildepanarra/anaconda3/lib/python3.11/site-packages/conda/plugins/types.py))
# WARNING:conda.plugins.manager:Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/Users/matildepanarra/anaconda3/lib/python3.11/site-packages/conda/plugins/types.py))
# Retrieving notices: ...working... DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/notices.json HTTP/1.1" 404 None
# ...

# %% [markdown]
# ### Option 3: uv (for this course)

# %%
# !uv add streamlit

# %% [markdown]
# ## ✅ Verify Installation
#
# Check that Streamlit is installed correctly:

# %%
import streamlit as st
print(f"✅ Streamlit version: {st.__version__}")
# Out:
# ✅ Streamlit version: 1.49.1

# %% [markdown]
# ## 🎯 Next Steps
#
# Now you're ready to build Streamlit apps! You can run Streamlit apps with:
#
# **Using pip/conda:**
# ```bash
# streamlit run your_app.py
# ```
#
# **Using uv (for this course):**
# ```bash
# uv run streamlit run your_app.py
# ```

# %% [markdown]
# ## 🎯 Next Steps
#
# Now you're ready to build Streamlit apps! You can run Streamlit apps with:
#
# ```bash
# uv run streamlit run your_app.py
# ```
